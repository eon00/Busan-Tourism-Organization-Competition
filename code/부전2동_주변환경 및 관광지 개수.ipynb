# %%
# 한글 폰트 다운 (다운 완료시 런타임 재시작 수행해주세요!)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 1s (9,798 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 122352 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20180306-3_all.deb ...
# Unpacking fonts-nanum (20180306-3) ...
# Setting up fonts-nanum (20180306-3) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install colour
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: colour
# Successfully installed colour-0.1.5

# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.9/dist-packages (from geopandas) (2.0.1)
# Collecting fiona>=1.8
#   Downloading Fiona-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 79.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from geopandas) (23.1)
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 83.5 MB/s eta 0:00:00
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (8.1.3)
# Collecting munch>=2.3.2
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (6.4.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (23.1.0)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.15.0)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.3 geopandas-0.12.2 munch-2.5.0 pyproj-3.5.0

# %%
pip install haversine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting haversine
#   Downloading haversine-2.8.0-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.8.0

# %%
## 라이브러리 설치
import os
import requests 
from tqdm import tqdm
from haversine import haversine, Unit

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns
import colour
from colour import Color
from matplotlib import rc
import missingno as msno

import json
import geopandas as gpd
import folium
from folium.features import CustomIcon

import warnings
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

rc('font', family='NanumBarunGothic')
warnings.filterwarnings("ignore")

# %%
hotel_df = pd.read_csv('/content/drive/MyDrive/부산 관광 아이디어 공모전/모델링) 세부분석 /부전2동/데이터/부산진구숙소(최종).csv', encoding='cp949')

# %%
hotel_df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# # 유형별 시설 집계

# %% [markdown]
# ## 업무

# %%
study_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'스터디카페',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000} 
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()
    study_num.append(total)

study_num
# Out:
# 100%|██████████| 9/9 [00:08<00:00,  1.03it/s]
# [{'documents': [{'address_name': '부산 부산진구 전포동 692-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸 > 플랜에이스터디카페',
#     'distance': '738',
#     'id': '434471129',
#     'phone': '051-802-7033',
#     'place_name': '플랜에이스터디카페 부산서면센터',
#     'place_url': 'http://place.map.kakao.com/434471129',
#     'road_address_name': '부산 부산진구 전포대로199번길 43',
#     'x': '129.062848157252',
#     'y': '35.1542334922606'},
#    {'address_name': '부산 부산진구 부전동 241-15',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '471',
#     'id': '926311966',
#     'phone': '0507-1435-5591',
#     'place_name': '이룸 스터디룸',
#     'place_url': 'http://place.map.kakao.com/926311966',
#     'road_address_name': '부산 부산진구 중앙대로 679-8',
#     'x': '129.058741466575',
#     'y': '35.1536806674899'},
#    {'address_name': '부산 부산진구 부전동 241-34',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '450',
#     'id': '1744934684',
#     'phone': '051-900-2110',
#     'place_name': '심블스터디룸',
#     'place_url': 'http://place.map.kakao.com/1744934684',
#     'road_address_name': '부산 부산진구 신천대로62번길 68',
#     'x': '129.058547042796',
#     'y': '35.1538029258005'},
#    {'address_name': '부산 부산진구 부전동 225-5',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '639',
#     'id': '881844521',
#     'phone': '051-808-5366',
#     'place_name': '도심속도서관',
#     'place_url': 'http://place.map.kakao.com/881844521',
#     'road_address_name': '부산 부산진구 중앙대로680번길 30',
#     'x': '129.060815162066',
#     'y': '35.153241678699'},
#    {'address_name': '부산 부산진구 부전동 198-3',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '597',
#     'id': '2118980357',
#     'phone': '010-9171-2284',
#     'place_name': '초심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/2118980357',
#     'road_address_name': '부산 부산진구 중앙대로680번길 23',
#     'x': '129.060561440483',
#     'y': '35.1535794258634'},
#    {'address_name': '부산 부산진구 부전동 198-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '582',
#     'id': '811172426',
#     'phone': '051-808-0910',
#     'place_name': '작심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/811172426',
#     'road_address_name': '부산 부산진구 중앙대로680번길 19-1',
#     'x': '129.060408385529',
#     'y': '35.1536451111885'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '541',
#     'id': '227971564',
#     'phone': '',
#     'place_name': '타임유스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/227971564',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '696',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '504',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부전동 223-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '690',
#     'id': '248558804',
#     'phone': '',
#     'place_name': '초월스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/248558804',
#     'road_address_name': '부산 부산진구 동천로 59',
#     'x': '129.062125017791',
#     'y': '35.1540142085033'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '640',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '541',
#     'id': '2067290395',
#     'phone': '',
#     'place_name': '타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/2067290395',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 전포동 595-21',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '942',
#     'id': '1877581699',
#     'phone': '051-804-1084',
#     'place_name': '다이아스터디카페',
#     'place_url': 'http://place.map.kakao.com/1877581699',
#     'road_address_name': '부산 부산진구 전포대로275번길 17',
#     'x': '129.064371813051',
#     'y': '35.1612933618101'},
#    {'address_name': '부산 부산진구 부암동 70-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '797',
#     'id': '443331740',
#     'phone': '051-818-3753',
#     'place_name': '아카데미프라자 부암센터',
#     'place_url': 'http://place.map.kakao.com/443331740',
#     'road_address_name': '부산 부산진구 시민공원로19번길 7',
#     'x': '129.051741240819',
#     'y': '35.1634743525445'},
#    {'address_name': '부산 부산진구 부전동 220-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '665',
#     'id': '261835879',
#     'phone': '051-205-0220',
#     'place_name': '패스스터디룸',
#     'place_url': 'http://place.map.kakao.com/261835879',
#     'road_address_name': '부산 부산진구 중앙대로680번길 45-5',
#     'x': '129.06161676504',
#     'y': '35.1537444021824'}],
#   'meta': {'is_end': False,
#    'pageable_count': 21,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 21}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 584',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '594',
#     'id': '2055340675',
#     'phone': '010-3046-5170',
#     'place_name': '화이트펜슬스터디카페 서면부전역점',
#     'place_url': 'http://place.map.kakao.com/2055340675',
#     'road_address_name': '부산 부산진구 전포대로298번길 1',
#     'x': '129.06560981629',
#     'y': '35.1634269260488'},
#    {'address_name': '부산 부산진구 전포동 595-21',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '520',
#     'id': '1877581699',
#     'phone': '051-804-1084',
#     'place_name': '다이아스터디카페',
#     'place_url': 'http://place.map.kakao.com/1877581699',
#     'road_address_name': '부산 부산진구 전포대로275번길 17',
#     'x': '129.064371813051',
#     'y': '35.1612933618101'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 전포동 874-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '463',
#     'id': '1712151074',
#     'phone': '',
#     'place_name': '셀독24시스터디카페',
#     'place_url': 'http://place.map.kakao.com/1712151074',
#     'road_address_name': '부산 부산진구 중앙대로 808',
#     'x': '129.064163109362',
#     'y': '35.1634993562041'},
#    {'address_name': '부산 부산진구 전포동 172-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '644',
#     'id': '1397094188',
#     'phone': '010-4964-7056',
#     'place_name': '빅타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/1397094188',
#     'road_address_name': '부산 부산진구 동성로118번길 31',
#     'x': '129.065938034539',
#     'y': '35.1616090934876'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '924',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부암동 70-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '672',
#     'id': '443331740',
#     'phone': '051-818-3753',
#     'place_name': '아카데미프라자 부암센터',
#     'place_url': 'http://place.map.kakao.com/443331740',
#     'road_address_name': '부산 부산진구 시민공원로19번길 7',
#     'x': '129.051741240819',
#     'y': '35.1634743525445'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 부전동 255-17',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '847',
#     'id': '1465274259',
#     'phone': '010-7465-5519',
#     'place_name': '인터뷰박스 부산서면점',
#     'place_url': 'http://place.map.kakao.com/1465274259',
#     'road_address_name': '부산 부산진구 중앙대로 701-6',
#     'x': '129.058738474222',
#     'y': '35.1554776369554'},
#    {'address_name': '부산 부산진구 전포동 660-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 모임공간',
#     'distance': '542',
#     'id': '1051026737',
#     'phone': '0507-1374-7188',
#     'place_name': '모임공간 숨 서면점',
#     'place_url': 'http://place.map.kakao.com/1051026737',
#     'road_address_name': '부산 부산진구 동천로 116',
#     'x': '129.062589316775',
#     'y': '35.1591483312681'}],
#   'meta': {'is_end': True,
#    'pageable_count': 10,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 10}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 584',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '594',
#     'id': '2055340675',
#     'phone': '010-3046-5170',
#     'place_name': '화이트펜슬스터디카페 서면부전역점',
#     'place_url': 'http://place.map.kakao.com/2055340675',
#     'road_address_name': '부산 부산진구 전포대로298번길 1',
#     'x': '129.06560981629',
#     'y': '35.1634269260488'},
#    {'address_name': '부산 부산진구 전포동 595-21',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '520',
#     'id': '1877581699',
#     'phone': '051-804-1084',
#     'place_name': '다이아스터디카페',
#     'place_url': 'http://place.map.kakao.com/1877581699',
#     'road_address_name': '부산 부산진구 전포대로275번길 17',
#     'x': '129.064371813051',
#     'y': '35.1612933618101'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 전포동 874-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '463',
#     'id': '1712151074',
#     'phone': '',
#     'place_name': '셀독24시스터디카페',
#     'place_url': 'http://place.map.kakao.com/1712151074',
#     'road_address_name': '부산 부산진구 중앙대로 808',
#     'x': '129.064163109362',
#     'y': '35.1634993562041'},
#    {'address_name': '부산 부산진구 전포동 172-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '644',
#     'id': '1397094188',
#     'phone': '010-4964-7056',
#     'place_name': '빅타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/1397094188',
#     'road_address_name': '부산 부산진구 동성로118번길 31',
#     'x': '129.065938034539',
#     'y': '35.1616090934876'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '924',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부암동 70-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '672',
#     'id': '443331740',
#     'phone': '051-818-3753',
#     'place_name': '아카데미프라자 부암센터',
#     'place_url': 'http://place.map.kakao.com/443331740',
#     'road_address_name': '부산 부산진구 시민공원로19번길 7',
#     'x': '129.051741240819',
#     'y': '35.1634743525445'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 부전동 255-17',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '847',
#     'id': '1465274259',
#     'phone': '010-7465-5519',
#     'place_name': '인터뷰박스 부산서면점',
#     'place_url': 'http://place.map.kakao.com/1465274259',
#     'road_address_name': '부산 부산진구 중앙대로 701-6',
#     'x': '129.058738474222',
#     'y': '35.1554776369554'},
#    {'address_name': '부산 부산진구 전포동 660-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 모임공간',
#     'distance': '542',
#     'id': '1051026737',
#     'phone': '0507-1374-7188',
#     'place_name': '모임공간 숨 서면점',
#     'place_url': 'http://place.map.kakao.com/1051026737',
#     'road_address_name': '부산 부산진구 동천로 116',
#     'x': '129.062589316775',
#     'y': '35.1591483312681'}],
#   'meta': {'is_end': True,
#    'pageable_count': 10,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 10}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 584',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '594',
#     'id': '2055340675',
#     'phone': '010-3046-5170',
#     'place_name': '화이트펜슬스터디카페 서면부전역점',
#     'place_url': 'http://place.map.kakao.com/2055340675',
#     'road_address_name': '부산 부산진구 전포대로298번길 1',
#     'x': '129.06560981629',
#     'y': '35.1634269260488'},
#    {'address_name': '부산 부산진구 전포동 595-21',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '520',
#     'id': '1877581699',
#     'phone': '051-804-1084',
#     'place_name': '다이아스터디카페',
#     'place_url': 'http://place.map.kakao.com/1877581699',
#     'road_address_name': '부산 부산진구 전포대로275번길 17',
#     'x': '129.064371813051',
#     'y': '35.1612933618101'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 전포동 874-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '463',
#     'id': '1712151074',
#     'phone': '',
#     'place_name': '셀독24시스터디카페',
#     'place_url': 'http://place.map.kakao.com/1712151074',
#     'road_address_name': '부산 부산진구 중앙대로 808',
#     'x': '129.064163109362',
#     'y': '35.1634993562041'},
#    {'address_name': '부산 부산진구 전포동 172-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '644',
#     'id': '1397094188',
#     'phone': '010-4964-7056',
#     'place_name': '빅타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/1397094188',
#     'road_address_name': '부산 부산진구 동성로118번길 31',
#     'x': '129.065938034539',
#     'y': '35.1616090934876'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '924',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부암동 70-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '672',
#     'id': '443331740',
#     'phone': '051-818-3753',
#     'place_name': '아카데미프라자 부암센터',
#     'place_url': 'http://place.map.kakao.com/443331740',
#     'road_address_name': '부산 부산진구 시민공원로19번길 7',
#     'x': '129.051741240819',
#     'y': '35.1634743525445'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 부전동 255-17',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '847',
#     'id': '1465274259',
#     'phone': '010-7465-5519',
#     'place_name': '인터뷰박스 부산서면점',
#     'place_url': 'http://place.map.kakao.com/1465274259',
#     'road_address_name': '부산 부산진구 중앙대로 701-6',
#     'x': '129.058738474222',
#     'y': '35.1554776369554'},
#    {'address_name': '부산 부산진구 전포동 660-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 모임공간',
#     'distance': '542',
#     'id': '1051026737',
#     'phone': '0507-1374-7188',
#     'place_name': '모임공간 숨 서면점',
#     'place_url': 'http://place.map.kakao.com/1051026737',
#     'road_address_name': '부산 부산진구 동천로 116',
#     'x': '129.062589316775',
#     'y': '35.1591483312681'}],
#   'meta': {'is_end': True,
#    'pageable_count': 10,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 10}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 584',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '594',
#     'id': '2055340675',
#     'phone': '010-3046-5170',
#     'place_name': '화이트펜슬스터디카페 서면부전역점',
#     'place_url': 'http://place.map.kakao.com/2055340675',
#     'road_address_name': '부산 부산진구 전포대로298번길 1',
#     'x': '129.06560981629',
#     'y': '35.1634269260488'},
#    {'address_name': '부산 부산진구 전포동 595-21',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '520',
#     'id': '1877581699',
#     'phone': '051-804-1084',
#     'place_name': '다이아스터디카페',
#     'place_url': 'http://place.map.kakao.com/1877581699',
#     'road_address_name': '부산 부산진구 전포대로275번길 17',
#     'x': '129.064371813051',
#     'y': '35.1612933618101'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 전포동 874-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '463',
#     'id': '1712151074',
#     'phone': '',
#     'place_name': '셀독24시스터디카페',
#     'place_url': 'http://place.map.kakao.com/1712151074',
#     'road_address_name': '부산 부산진구 중앙대로 808',
#     'x': '129.064163109362',
#     'y': '35.1634993562041'},
#    {'address_name': '부산 부산진구 전포동 172-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '644',
#     'id': '1397094188',
#     'phone': '010-4964-7056',
#     'place_name': '빅타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/1397094188',
#     'road_address_name': '부산 부산진구 동성로118번길 31',
#     'x': '129.065938034539',
#     'y': '35.1616090934876'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '924',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부암동 70-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '672',
#     'id': '443331740',
#     'phone': '051-818-3753',
#     'place_name': '아카데미프라자 부암센터',
#     'place_url': 'http://place.map.kakao.com/443331740',
#     'road_address_name': '부산 부산진구 시민공원로19번길 7',
#     'x': '129.051741240819',
#     'y': '35.1634743525445'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '932',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 부전동 255-17',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '847',
#     'id': '1465274259',
#     'phone': '010-7465-5519',
#     'place_name': '인터뷰박스 부산서면점',
#     'place_url': 'http://place.map.kakao.com/1465274259',
#     'road_address_name': '부산 부산진구 중앙대로 701-6',
#     'x': '129.058738474222',
#     'y': '35.1554776369554'},
#    {'address_name': '부산 부산진구 전포동 660-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 모임공간',
#     'distance': '542',
#     'id': '1051026737',
#     'phone': '0507-1374-7188',
#     'place_name': '모임공간 숨 서면점',
#     'place_url': 'http://place.map.kakao.com/1051026737',
#     'road_address_name': '부산 부산진구 동천로 116',
#     'x': '129.062589316775',
#     'y': '35.1591483312681'}],
#   'meta': {'is_end': True,
#    'pageable_count': 10,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 10}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 692-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸 > 플랜에이스터디카페',
#     'distance': '425',
#     'id': '434471129',
#     'phone': '051-802-7033',
#     'place_name': '플랜에이스터디카페 부산서면센터',
#     'place_url': 'http://place.map.kakao.com/434471129',
#     'road_address_name': '부산 부산진구 전포대로199번길 43',
#     'x': '129.062848157252',
#     'y': '35.1542334922606'},
#    {'address_name': '부산 부산진구 부전동 241-15',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '188',
#     'id': '926311966',
#     'phone': '0507-1435-5591',
#     'place_name': '이룸 스터디룸',
#     'place_url': 'http://place.map.kakao.com/926311966',
#     'road_address_name': '부산 부산진구 중앙대로 679-8',
#     'x': '129.058741466575',
#     'y': '35.1536806674899'},
#    {'address_name': '부산 부산진구 부전동 241-34',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '172',
#     'id': '1744934684',
#     'phone': '051-900-2110',
#     'place_name': '심블스터디룸',
#     'place_url': 'http://place.map.kakao.com/1744934684',
#     'road_address_name': '부산 부산진구 신천대로62번길 68',
#     'x': '129.058547042796',
#     'y': '35.1538029258005'},
#    {'address_name': '부산 부산진구 부전동 225-5',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '322',
#     'id': '881844521',
#     'phone': '051-808-5366',
#     'place_name': '도심속도서관',
#     'place_url': 'http://place.map.kakao.com/881844521',
#     'road_address_name': '부산 부산진구 중앙대로680번길 30',
#     'x': '129.060815162066',
#     'y': '35.153241678699'},
#    {'address_name': '부산 부산진구 부전동 198-3',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '279',
#     'id': '2118980357',
#     'phone': '010-9171-2284',
#     'place_name': '초심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/2118980357',
#     'road_address_name': '부산 부산진구 중앙대로680번길 23',
#     'x': '129.060561440483',
#     'y': '35.1535794258634'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '404',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 부전동 198-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '264',
#     'id': '811172426',
#     'phone': '051-808-0910',
#     'place_name': '작심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/811172426',
#     'road_address_name': '부산 부산진구 중앙대로680번길 19-1',
#     'x': '129.060408385529',
#     'y': '35.1536451111885'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '232',
#     'id': '227971564',
#     'phone': '',
#     'place_name': '타임유스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/227971564',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '188',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부전동 223-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '371',
#     'id': '248558804',
#     'phone': '',
#     'place_name': '초월스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/248558804',
#     'road_address_name': '부산 부산진구 동천로 59',
#     'x': '129.062125017791',
#     'y': '35.1540142085033'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '340',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '232',
#     'id': '2067290395',
#     'phone': '',
#     'place_name': '타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/2067290395',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 전포동 339-31',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '747',
#     'id': '1446548157',
#     'phone': '',
#     'place_name': '스터디고 서면전포점',
#     'place_url': 'http://place.map.kakao.com/1446548157',
#     'road_address_name': '부산 부산진구 전포대로200번길 17',
#     'x': '129.066541553641',
#     'y': '35.1546688692551'},
#    {'address_name': '부산 부산진구 전포동 595-21',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '856',
#     'id': '1877581699',
#     'phone': '051-804-1084',
#     'place_name': '다이아스터디카페',
#     'place_url': 'http://place.map.kakao.com/1877581699',
#     'road_address_name': '부산 부산진구 전포대로275번길 17',
#     'x': '129.064371813051',
#     'y': '35.1612933618101'},
#    {'address_name': '부산 부산진구 전포동 172-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '978',
#     'id': '1397094188',
#     'phone': '010-4964-7056',
#     'place_name': '빅타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/1397094188',
#     'road_address_name': '부산 부산진구 동성로118번길 31',
#     'x': '129.065938034539',
#     'y': '35.1616090934876'}],
#   'meta': {'is_end': False,
#    'pageable_count': 23,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 23}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 692-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸 > 플랜에이스터디카페',
#     'distance': '649',
#     'id': '434471129',
#     'phone': '051-802-7033',
#     'place_name': '플랜에이스터디카페 부산서면센터',
#     'place_url': 'http://place.map.kakao.com/434471129',
#     'road_address_name': '부산 부산진구 전포대로199번길 43',
#     'x': '129.062848157252',
#     'y': '35.1542334922606'},
#    {'address_name': '부산 부산진구 부전동 241-15',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '305',
#     'id': '926311966',
#     'phone': '0507-1435-5591',
#     'place_name': '이룸 스터디룸',
#     'place_url': 'http://place.map.kakao.com/926311966',
#     'road_address_name': '부산 부산진구 중앙대로 679-8',
#     'x': '129.058741466575',
#     'y': '35.1536806674899'},
#    {'address_name': '부산 부산진구 부전동 241-34',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '283',
#     'id': '1744934684',
#     'phone': '051-900-2110',
#     'place_name': '심블스터디룸',
#     'place_url': 'http://place.map.kakao.com/1744934684',
#     'road_address_name': '부산 부산진구 신천대로62번길 68',
#     'x': '129.058547042796',
#     'y': '35.1538029258005'},
#    {'address_name': '부산 부산진구 부전동 225-5',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '497',
#     'id': '881844521',
#     'phone': '051-808-5366',
#     'place_name': '도심속도서관',
#     'place_url': 'http://place.map.kakao.com/881844521',
#     'road_address_name': '부산 부산진구 중앙대로680번길 30',
#     'x': '129.060815162066',
#     'y': '35.153241678699'},
#    {'address_name': '부산 부산진구 부전동 198-3',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '462',
#     'id': '2118980357',
#     'phone': '010-9171-2284',
#     'place_name': '초심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/2118980357',
#     'road_address_name': '부산 부산진구 중앙대로680번길 23',
#     'x': '129.060561440483',
#     'y': '35.1535794258634'},
#    {'address_name': '부산 부산진구 부전동 198-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '446',
#     'id': '811172426',
#     'phone': '051-808-0910',
#     'place_name': '작심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/811172426',
#     'road_address_name': '부산 부산진구 중앙대로680번길 19-1',
#     'x': '129.060408385529',
#     'y': '35.1536451111885'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '392',
#     'id': '227971564',
#     'phone': '',
#     'place_name': '타임유스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/227971564',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '643',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '418',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부전동 223-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '588',
#     'id': '248558804',
#     'phone': '',
#     'place_name': '초월스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/248558804',
#     'road_address_name': '부산 부산진구 동천로 59',
#     'x': '129.062125017791',
#     'y': '35.1540142085033'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '392',
#     'id': '2067290395',
#     'phone': '',
#     'place_name': '타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/2067290395',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '576',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 전포동 339-31',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '982',
#     'id': '1446548157',
#     'phone': '',
#     'place_name': '스터디고 서면전포점',
#     'place_url': 'http://place.map.kakao.com/1446548157',
#     'road_address_name': '부산 부산진구 전포대로200번길 17',
#     'x': '129.066541553641',
#     'y': '35.1546688692551'},
#    {'address_name': '부산 부산진구 부전동 220-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '549',
#     'id': '261835879',
#     'phone': '051-205-0220',
#     'place_name': '패스스터디룸',
#     'place_url': 'http://place.map.kakao.com/261835879',
#     'road_address_name': '부산 부산진구 중앙대로680번길 45-5',
#     'x': '129.06161676504',
#     'y': '35.1537444021824'},
#    {'address_name': '부산 부산진구 부전동 224-22',
#     'category_group_code': 'CE7',
#     'category_group_name': '카페',
#     'category_name': '음식점 > 카페',
#     'distance': '551',
#     'id': '1857971874',
#     'phone': '051-818-8886',
#     'place_name': '카페 프리아트',
#     'place_url': 'http://place.map.kakao.com/1857971874',
#     'road_address_name': '부산 부산진구 중앙대로680번길 40',
#     'x': '129.061455857545',
#     'y': '35.1532379843659'}],
#   'meta': {'is_end': False,
#    'pageable_count': 20,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 20}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 692-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸 > 플랜에이스터디카페',
#     'distance': '477',
#     'id': '434471129',
#     'phone': '051-802-7033',
#     'place_name': '플랜에이스터디카페 부산서면센터',
#     'place_url': 'http://place.map.kakao.com/434471129',
#     'road_address_name': '부산 부산진구 전포대로199번길 43',
#     'x': '129.062848157252',
#     'y': '35.1542334922606'},
#    {'address_name': '부산 부산진구 부전동 241-15',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '204',
#     'id': '926311966',
#     'phone': '0507-1435-5591',
#     'place_name': '이룸 스터디룸',
#     'place_url': 'http://place.map.kakao.com/926311966',
#     'road_address_name': '부산 부산진구 중앙대로 679-8',
#     'x': '129.058741466575',
#     'y': '35.1536806674899'},
#    {'address_name': '부산 부산진구 부전동 241-34',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '184',
#     'id': '1744934684',
#     'phone': '051-900-2110',
#     'place_name': '심블스터디룸',
#     'place_url': 'http://place.map.kakao.com/1744934684',
#     'road_address_name': '부산 부산진구 신천대로62번길 68',
#     'x': '129.058547042796',
#     'y': '35.1538029258005'},
#    {'address_name': '부산 부산진구 부전동 225-5',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '361',
#     'id': '881844521',
#     'phone': '051-808-5366',
#     'place_name': '도심속도서관',
#     'place_url': 'http://place.map.kakao.com/881844521',
#     'road_address_name': '부산 부산진구 중앙대로680번길 30',
#     'x': '129.060815162066',
#     'y': '35.153241678699'},
#    {'address_name': '부산 부산진구 부전동 198-3',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '319',
#     'id': '2118980357',
#     'phone': '010-9171-2284',
#     'place_name': '초심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/2118980357',
#     'road_address_name': '부산 부산진구 중앙대로680번길 23',
#     'x': '129.060561440483',
#     'y': '35.1535794258634'},
#    {'address_name': '부산 부산진구 부전동 198-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '304',
#     'id': '811172426',
#     'phone': '051-808-0910',
#     'place_name': '작심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/811172426',
#     'road_address_name': '부산 부산진구 중앙대로680번길 19-1',
#     'x': '129.060408385529',
#     'y': '35.1536451111885'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '458',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '264',
#     'id': '227971564',
#     'phone': '',
#     'place_name': '타임유스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/227971564',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '240',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부전동 223-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '421',
#     'id': '248558804',
#     'phone': '',
#     'place_name': '초월스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/248558804',
#     'road_address_name': '부산 부산진구 동천로 59',
#     'x': '129.062125017791',
#     'y': '35.1540142085033'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '393',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '264',
#     'id': '2067290395',
#     'phone': '',
#     'place_name': '타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/2067290395',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 전포동 339-31',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '800',
#     'id': '1446548157',
#     'phone': '',
#     'place_name': '스터디고 서면전포점',
#     'place_url': 'http://place.map.kakao.com/1446548157',
#     'road_address_name': '부산 부산진구 전포대로200번길 17',
#     'x': '129.066541553641',
#     'y': '35.1546688692551'},
#    {'address_name': '부산 부산진구 전포동 595-21',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '891',
#     'id': '1877581699',
#     'phone': '051-804-1084',
#     'place_name': '다이아스터디카페',
#     'place_url': 'http://place.map.kakao.com/1877581699',
#     'road_address_name': '부산 부산진구 전포대로275번길 17',
#     'x': '129.064371813051',
#     'y': '35.1612933618101'},
#    {'address_name': '부산 부산진구 부전동 220-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '391',
#     'id': '261835879',
#     'phone': '051-205-0220',
#     'place_name': '패스스터디룸',
#     'place_url': 'http://place.map.kakao.com/261835879',
#     'road_address_name': '부산 부산진구 중앙대로680번길 45-5',
#     'x': '129.06161676504',
#     'y': '35.1537444021824'}],
#   'meta': {'is_end': False,
#    'pageable_count': 22,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 22}},
#  {'documents': [{'address_name': '부산 부산진구 전포동 692-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸 > 플랜에이스터디카페',
#     'distance': '649',
#     'id': '434471129',
#     'phone': '051-802-7033',
#     'place_name': '플랜에이스터디카페 부산서면센터',
#     'place_url': 'http://place.map.kakao.com/434471129',
#     'road_address_name': '부산 부산진구 전포대로199번길 43',
#     'x': '129.062848157252',
#     'y': '35.1542334922606'},
#    {'address_name': '부산 부산진구 부전동 241-15',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '305',
#     'id': '926311966',
#     'phone': '0507-1435-5591',
#     'place_name': '이룸 스터디룸',
#     'place_url': 'http://place.map.kakao.com/926311966',
#     'road_address_name': '부산 부산진구 중앙대로 679-8',
#     'x': '129.058741466575',
#     'y': '35.1536806674899'},
#    {'address_name': '부산 부산진구 부전동 241-34',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '283',
#     'id': '1744934684',
#     'phone': '051-900-2110',
#     'place_name': '심블스터디룸',
#     'place_url': 'http://place.map.kakao.com/1744934684',
#     'road_address_name': '부산 부산진구 신천대로62번길 68',
#     'x': '129.058547042796',
#     'y': '35.1538029258005'},
#    {'address_name': '부산 부산진구 부전동 225-5',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '497',
#     'id': '881844521',
#     'phone': '051-808-5366',
#     'place_name': '도심속도서관',
#     'place_url': 'http://place.map.kakao.com/881844521',
#     'road_address_name': '부산 부산진구 중앙대로680번길 30',
#     'x': '129.060815162066',
#     'y': '35.153241678699'},
#    {'address_name': '부산 부산진구 부전동 198-3',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '462',
#     'id': '2118980357',
#     'phone': '010-9171-2284',
#     'place_name': '초심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/2118980357',
#     'road_address_name': '부산 부산진구 중앙대로680번길 23',
#     'x': '129.060561440483',
#     'y': '35.1535794258634'},
#    {'address_name': '부산 부산진구 부전동 198-4',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '446',
#     'id': '811172426',
#     'phone': '051-808-0910',
#     'place_name': '작심스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/811172426',
#     'road_address_name': '부산 부산진구 중앙대로680번길 19-1',
#     'x': '129.060408385529',
#     'y': '35.1536451111885'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '392',
#     'id': '227971564',
#     'phone': '',
#     'place_name': '타임유스터디카페 부산서면점',
#     'place_url': 'http://place.map.kakao.com/227971564',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 전포동 683-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '643',
#     'id': '1545318070',
#     'phone': '010-5376-3217',
#     'place_name': '화이트펜슬스터디카페 부산놀이마루점',
#     'place_url': 'http://place.map.kakao.com/1545318070',
#     'road_address_name': '부산 부산진구 전포대로209번길 43',
#     'x': '129.0628197493112',
#     'y': '35.15528112634581'},
#    {'address_name': '부산 부산진구 부전동 187-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '418',
#     'id': '931700269',
#     'phone': '',
#     'place_name': 'W스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/931700269',
#     'road_address_name': '부산 부산진구 중앙대로680번가길 33-7',
#     'x': '129.060359769852',
#     'y': '35.1548498913798'},
#    {'address_name': '부산 부산진구 부전동 223-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '588',
#     'id': '248558804',
#     'phone': '',
#     'place_name': '초월스터디카페 서면점',
#     'place_url': 'http://place.map.kakao.com/248558804',
#     'road_address_name': '부산 부산진구 동천로 59',
#     'x': '129.062125017791',
#     'y': '35.1540142085033'},
#    {'address_name': '부산 부산진구 부전동 197-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '392',
#     'id': '2067290395',
#     'phone': '',
#     'place_name': '타임스터디카페',
#     'place_url': 'http://place.map.kakao.com/2067290395',
#     'road_address_name': '부산 부산진구 신천대로50번길 61',
#     'x': '129.059735069023',
#     'y': '35.153573657149'},
#    {'address_name': '부산 부산진구 부전동 170-1',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '576',
#     'id': '452300179',
#     'phone': '010-7696-4720',
#     'place_name': '아마존 토크앤클릭',
#     'place_url': 'http://place.map.kakao.com/452300179',
#     'road_address_name': '부산 부산진구 동천로 71',
#     'x': '129.06210363603478',
#     'y': '35.15507974622025'},
#    {'address_name': '부산 부산진구 전포동 339-31',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여 > 스터디카페,스터디룸',
#     'distance': '982',
#     'id': '1446548157',
#     'phone': '',
#     'place_name': '스터디고 서면전포점',
#     'place_url': 'http://place.map.kakao.com/1446548157',
#     'road_address_name': '부산 부산진구 전포대로200번길 17',
#     'x': '129.066541553641',
#     'y': '35.1546688692551'},
#    {'address_name': '부산 부산진구 부전동 220-7',
#     'category_group_code': '',
#     'category_group_name': '',
#     'category_name': '서비스,산업 > 전문대행 > 공간대여',
#     'distance': '549',
#     'id': '261835879',
#     'phone': '051-205-0220',
#     'place_name': '패스스터디룸',
#     'place_url': 'http://place.map.kakao.com/261835879',
#     'road_address_name': '부산 부산진구 중앙대로680번길 45-5',
#     'x': '129.06161676504',
#     'y': '35.1537444021824'},
#    {'address_name': '부산 부산진구 부전동 224-22',
#     'category_group_code': 'CE7',
#     'category_group_name': '카페',
#     'category_name': '음식점 > 카페',
#     'distance': '551',
#     'id': '1857971874',
#     'phone': '051-818-8886',
#     'place_name': '카페 프리아트',
#     'place_url': 'http://place.map.kakao.com/1857971874',
#     'road_address_name': '부산 부산진구 중앙대로680번길 40',
#     'x': '129.061455857545',
#     'y': '35.1532379843659'}],
#   'meta': {'is_end': False,
#    'pageable_count': 20,
#    'same_name': {'keyword': '스터디카페', 'region': [], 'selected_region': ''},
#    'total_count': 20}}]

# %%
study_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'스터디카페',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000} 
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()
    study_num.append(len([s for s in [i['category_name'] for i in total['documents']] if "스터디카페" in s]))

study_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.13it/s]
# [14, 8, 8, 8, 8, 15, 13, 14, 13]

# %%
hotel_df['스터디카페'] = study_num

# %%
office_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'공유오피스',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()
    office_num.append(len([s for s in [i['category_name'] for i in total['documents']] if "공유오피스" in s]))

office_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.18it/s]
# [6, 3, 3, 3, 3, 9, 8, 8, 8]

# %%
hotel_df['공유오피스'] = office_num

# %% [markdown]
# ## 관광

# %%
tour_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'관광지',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 10000} # 관광지만 10km
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    tour_num.append(total)

tour_num
# Out:
# 100%|██████████| 9/9 [00:09<00:00,  1.01s/it]
# [799, 793, 793, 793, 793, 789, 788, 789, 788]

# %%
hotel_df['관광지'] = tour_num

# %% [markdown]
# ## 편의

# %%
pharmacy_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'약국',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    pharmacy_num.append(total)

pharmacy_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# [79, 72, 72, 72, 72, 88, 83, 88, 83]

# %%
hotel_df['약국'] = pharmacy_num

# %%
hospital_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'병원',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    hospital_num.append(total)

hospital_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# [485, 459, 459, 459, 459, 519, 497, 517, 497]

# %%
hotel_df['병원'] = hospital_num

# %%
# 병원의 경우, if 노인, 요양병원도 함께 집계된다면 해당 경우는 빼줌
# hotel_df['병원'] = [ai - bi for ai, bi in zip(hospital_num, nursing_hospital_num)]

# %%
bank_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'은행',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    bank_num.append(total)
bank_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# [160, 132, 132, 132, 132, 165, 154, 163, 154]

# %%
hotel_df['은행'] = bank_num

# %%
supermarket_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'대형마트',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    supermarket_num.append(total)
supermarket_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.18it/s]
# [4, 4, 4, 4, 4, 3, 2, 3, 2]

# %%
hotel_df['대형마트'] = supermarket_num

# %%
convenience_store_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'편의점',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    convenience_store_num.append(total)
convenience_store_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.13it/s]
# [130, 101, 101, 101, 101, 151, 134, 148, 134]

# %%
hotel_df['편의점'] = convenience_store_num

# %%
sing_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'노래방',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    sing_num.append(total)
sing_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.16it/s]
# [115, 91, 91, 91, 91, 121, 114, 118, 114]

# %%
hotel_df['노래방'] = sing_num

# %%
pc_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'게임방,PC방',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    pc_num.append(total)
pc_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.14it/s]
# [9, 5, 5, 5, 5, 9, 9, 9, 9]

# %%
hotel_df['게임방,PC방'] = pc_num

# %%
park_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'공원',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json() # ['meta']['total_count']
    park_num.append(len([s for s in [i['category_name'] for i in total['documents']] if "여행 > 공원" in s]))
park_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.18it/s]
# [3, 5, 5, 5, 5, 2, 1, 2, 1]

# %%
hotel_df['공원'] = park_num

# %%
theater_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'영화관',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    theater_num.append(total)
theater_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.13it/s]
# [5, 4, 4, 4, 4, 6, 6, 6, 6]

# %%
hotel_df['영화관'] = theater_num

# %%
library_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'도서관',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json() # ['meta']['total_count']
    library_num.append(len([s for s in [i['category_name'] for i in total['documents']] if "교육,학문 > 학습시설 > 도서관" in s]))
library_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.20it/s]
# [8, 9, 9, 9, 9, 11, 6, 12, 6]

# %%
hotel_df['도서관'] = library_num

# %%
gym_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'헬스장',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    gym_num.append(total)

gym_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.20it/s]
# [61, 50, 50, 50, 50, 73, 60, 70, 60]

# %%
hotel_df['헬스장'] = gym_num

# %%
golf_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'골프연습장',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    golf_num.append(total)

golf_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.19it/s]
# [19, 10, 10, 10, 10, 17, 15, 17, 15]

# %%
hotel_df['골프연습장'] = golf_num

# %%
swimming_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'수영장',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()# ['meta']['total_count']
    swimming_num.append(len([s for s in [i['category_name'] for i in total['documents']] if "수영장" in s]))

swimming_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
hotel_df['수영장'] = swimming_num

# %% [markdown]
# ## 식음

# %%
restaurant_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'음식점',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    restaurant_num.append(total)
restaurant_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# [3420, 2848, 2848, 2848, 2848, 3985, 3466, 3946, 3466]

# %%
hotel_df['음식점'] = restaurant_num

# %%
cafe_num = []
for i in tqdm(range(0,len(hotel_df))):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
    params = {'query':'커피전문점',
                'x': hotel_df["경도"][i],
              'y':hotel_df['위도'][i],
              'radius': 1000}
    headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    cafe_num.append(total)
cafe_num
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# [515, 414, 414, 414, 414, 679, 539, 663, 539]

# %%
hotel_df['커피전문점'] = cafe_num

# %% [markdown]
# ## 교통

# %%
bus_df = pd.read_csv('/content/drive/MyDrive/부산 관광 아이디어 공모전/모델링) 세부분석 /부전2동/데이터/부산광역시_버스정류소.csv')
subway_df = pd.read_csv('/content/drive/MyDrive/부산 관광 아이디어 공모전/모델링) 세부분석 /부전2동/데이터/부산교통공사_도시철도역사정보.csv', encoding='utf-16')

# %%
bus_df
# Out:
#       arsno    bstopid      bstopnm        gpsx       gpsy stoptype
# 0     01001  167970102        영주삼거리  129.033262  35.115323       일반
# 1     01002  169310303        영주삼거리  129.033030  35.115283       일반
# 2     01003  167970301        시민아파트  129.031678  35.115075       일반
# 3     01004  167840102        시민아파트  129.032160  35.114921       일반
# 4     01005  167970302  중앙공원.민주공원입구  129.029858  35.114473       일반
# ...     ...        ...          ...         ...        ...      ...
# 8517    ---  510740000    좌2동행정복지센터  129.183119  35.169047       마을
# 8518    ---  510750000       좌동재래시장  129.172913  35.173195       마을
# 8519    ---  510760000       좌동재래시장  129.173247  35.173347       마을
# 8520    ---  510770000     한마음스포츠센터  129.177295  35.180100       마을
# 8521    ---  510780000      해운대문화회관  129.174878  35.170511       마을
#
# [8522 rows x 6 columns]

# %%
subway_df
# Out:
#     역번호\t역사명\t노선번호\t노선명\t영문역사명\t한자역사명\t환승역구분\t환승노선번호\t환승노선명\t역위도\t역경도\t운영기관명\t역사도로명주소\t역사전화번호\t데이터기준일자
# 0    95\t다대포해수욕장\tS2601\t부산도시철도 1호선\tDadaepo Beach\...
# 1    96\t다대포항역\tS2601\t부산도시철도 1호선\tDadaepo Harbor\t...
# 2    97\t낫개역\tS2601\t부산도시철도 1호선\tNatgae\t羅 浦\t일반역\t...
# 3    98\t신장림역\tS2601\t부산도시철도 1호선\tSinjangnim\t新長林\t...
# 4    99\t장림역\tS2601\t부산도시철도 1호선\tJangnim\t長林\t일반역\t...
# ..                                                 ...
# 109  410\t석대역\tS2604\t부산도시철도 4호선\tSeokdae\t石坮\t일반역\...
# 110  411\t영산대역\tS2604\t부산도시철도 4호선\tYoungsan Univ.\t...
# 111  412\t윗반송역\tS2604\t부산도시철도 4호선\tWitbansong\t上盘松\...
# 112  413\t고촌역\tS2604\t부산도시철도 4호선\tGochon\t古村\t일반역\t...
# 113  414\t안평역\tS2604\t부산도시철도 4호선\tAnpyeong\t安平\t일반역...
#
# [114 rows x 1 columns]

# %%
# 지하철역 데이터 정리
subway_df = pd.DataFrame(subway_df.iloc[:,0].str.split('\t').tolist(), columns=subway_df.columns[0].split('\t'))

# %%
subway_df
# Out:
#      역번호      역사명   노선번호         노선명           영문역사명    한자역사명 환승역구분 환승노선번호  \
# 0     95  다대포해수욕장  S2601  부산도시철도 1호선   Dadaepo Beach  多大浦海水浴場   일반역
# 1     96    다대포항역  S2601  부산도시철도 1호선  Dadaepo Harbor     多大浦港   일반역
# 2     97      낫개역  S2601  부산도시철도 1호선          Natgae      羅 浦   일반역
# 3     98     신장림역  S2601  부산도시철도 1호선      Sinjangnim      新長林   일반역
# 4     99      장림역  S2601  부산도시철도 1호선         Jangnim       長林   일반역
# ..   ...      ...    ...         ...             ...      ...   ...    ...
# 109  410      석대역  S2604  부산도시철도 4호선         Seokdae       石坮   일반역
# 110  411     영산대역  S2604  부산도시철도 4호선  Youngsan Univ.      靈山大   일반역
# 111  412     윗반송역  S2604  부산도시철도 4호선      Witbansong      上盘松   일반역
# 112  413      고촌역  S2604  부산도시철도 4호선          Gochon       古村   일반역
# 113  414      안평역  S2604  부산도시철도 4호선        Anpyeong       安平   일반역
#
#     환승노선명          역위도          역경도   운영기관명                 역사도로명주소  \
# 0             35.04867     128.9641  부산교통공사    부산광역시 사하구 다대로 지하 692
# 1             35.05782     128.9713  부산교통공사    부산광역시 사하구 다대로 지하 548
# 2            35.065265   128.979873  부산교통공사    부산광역시 사하구 다대로 지하 422
# 3            35.074433   128.977041  부산교통공사    부산광역시 사하구 다대로 지하 310
# 4             35.08109     128.9775  부산교통공사    부산광역시 사하구 다대로 지하 230
# ..    ...          ...          ...     ...                     ...
# 109        35.21811162   129.137179  부산교통공사     부산광역시 해운대구 석대천로 121
# 110          35.225777   129.146149  부산교통공사      부산광역시 해운대구 반송로 803
# 111          35.232506   129.154024  부산교통공사      부산광역시 해운대구 반송로 917
# 112          35.236031  129.1604437  부산교통공사   부산광역시 기장군 철마면 반송로 991
# 113          35.237363   129.171823  부산교통공사  부산광역시 기장군 철마면 반송로 1101
#
#            역사전화번호     데이터기준일자
# 0    051-678-6195  2021-02-26
# 1    051-678-6196  2021-02-26
# 2    051-678-6197  2021-02-26
# 3    051-678-6198  2021-02-26
# 4    051-618-6199  2021-02-26
# ..            ...         ...
# 109  051-678-6410  2021-02-26
# 110  051-678-6411  2021-02-26
# 111  051-678-6412  2021-02-26
# 112  051-678-6413  2021-02-26
# 113  051-678-6414  2021-02-26
#
# [114 rows x 15 columns]

# %%
# 위경도 변수 실수형으로 변경
subway_df = subway_df.astype({'역위도':'float', '역경도':'float'})

# %%
# 1km 내 버스정류장 개수
bus_num = []

for i in tqdm(range(len(hotel_df))):

  n = 0
  hotel_location = (hotel_df.위도[i], hotel_df.경도[i])

  for j in range(len(bus_df)):

    bus_location = (bus_df.gpsy[j], bus_df.gpsx[j])

    if haversine(hotel_location, bus_location, unit = 'km') <= 1:
      n += 1

  bus_num.append(n)
# Out:
# 100%|██████████| 9/9 [00:01<00:00,  5.21it/s]

# %%
hotel_df['버스정류장'] = bus_num

# %%
# 1km 내 지하철역 개수
subway_num = []

for i in tqdm(range(len(hotel_df))):

  n = 0
  hotel_location = (hotel_df.위도[i], hotel_df.경도[i])

  for j in range(len(subway_df)):

    subway_location = (subway_df.역위도[j], subway_df.역경도[j])

    if haversine(hotel_location, subway_location, unit = 'km') <= 1:
      n += 1

  subway_num.append(n)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 319.38it/s]

# %%
hotel_df['지하철역'] = subway_num

# %%
hotel_df
# Out:
#        숙박업소명                           주소         위도          경도  스터디카페  \
# 0  (주)부산롯데호텔         부산광역시 부산진구 가야대로 772   35.156972  129.055466     14
# 1       퀸스호텔           부산광역시 부산진구 부전로 56   35.163113  129.059102      8
# 2   부산비즈니스호텔           부산광역시 부산진구 부전로 67   35.163113  129.059102      8
# 3  TRT HOTEL         부산광역시 부산진구 부전로 33-1   35.163113  129.059102      8
# 4   (주)샤이어호텔         부산광역시 부산진구 부전로 18-5   35.163113  129.059102      8
# 5     트래블라이트       부산광역시 부산진구 서면로68번길 52   35.155352  129.058385     15
# 6      라이온호텔  부산광역시 부산진구 중앙대로691번가길 14-7   35.154961  129.055775     13
# 7  사우스반데코 호텔            부산광역시 부산진구 서면로 6   35.155351  129.057795     14
# 8      하운드호텔    부산광역시 부산진구 중앙대로691번가길 10   35.154961  129.055775     13
#
#    공유오피스  관광지  약국   병원   은행  ...  공원  영화관  도서관  헬스장  골프연습장  수영장   음식점  커피전문점  \
# 0      6  799  79  485  160  ...   3    5    8   61     19    0  3420    515
# 1      3  793  72  459  132  ...   5    4    9   50     10    0  2848    414
# 2      3  793  72  459  132  ...   5    4    9   50     10    0  2848    414
# 3      3  793  72  459  132  ...   5    4    9   50     10    0  2848    414
# 4      3  793  72  459  132  ...   5    4    9   50     10    0  2848    414
# 5      9  789  88  519  165  ...   2    6   11   73     17    0  3985    679
# 6      8  788  83  497  154  ...   1    6    6   60     15    0  3466    539
# 7      8  789  88  517  163  ...   2    6   12   70     17    0  3946    663
# 8      8  788  83  497  154  ...   1    6    6   60     15    0  3466    539
#
#    버스정류장  지하철역
# 0    111     5
# 1    142     3
# 2    142     3
# 3    142     3
# 4    142     3
# 5    122     6
# 6    104     5
# 7    124     6
# 8    104     5
#
# [9 rows x 24 columns]

# %% [markdown]
# # 유형별 변수 정리

# %%
hotel_df.columns
# Out:
# Index(['숙박업소명', '주소', '위도', '경도', '스터디카페', '공유오피스', '관광지', '약국', '병원', '은행',
#        '대형마트', '편의점', '노래방', '게임방,PC방', '공원', '영화관', '도서관', '헬스장', '골프연습장',
#        '수영장', '음식점', '커피전문점', '버스정류장', '지하철역'],
#       dtype='object')

# %%
# 편의시설
hotel_df['편의시설'] = sum([hotel_df['약국'], hotel_df['병원'], hotel_df['은행'], hotel_df['대형마트'], hotel_df['편의점'], hotel_df['노래방'], hotel_df['게임방,PC방'],
                        hotel_df['공원'], hotel_df['영화관'], hotel_df['도서관'], hotel_df['헬스장'], hotel_df['골프연습장'], hotel_df['수영장']])

# %%
# 업무시설
hotel_df['업무시설'] = sum([hotel_df['스터디카페'], hotel_df['공유오피스']])

# %%
# 식음시설
hotel_df['식음시설'] = sum([hotel_df['음식점'], hotel_df['커피전문점']])

# %%
# 교통시설
hotel_df['교통시설'] = sum([hotel_df['버스정류장'], hotel_df['지하철역']])

# %%
hotel_df_radar = hotel_df[['숙박업소명', '주소', '편의시설', '업무시설', '식음시설', '교통시설', '관광지']]

# %%
hotel_df_radar
# Out:
#        숙박업소명                           주소  편의시설  업무시설  식음시설  교통시설  관광지
# 0  (주)부산롯데호텔         부산광역시 부산진구 가야대로 772   1078    20  3935   116  799
# 1       퀸스호텔           부산광역시 부산진구 부전로 56    942    11  3262   145  793
# 2   부산비즈니스호텔           부산광역시 부산진구 부전로 67    942    11  3262   145  793
# 3  TRT HOTEL         부산광역시 부산진구 부전로 33-1    942    11  3262   145  793
# 4   (주)샤이어호텔         부산광역시 부산진구 부전로 18-5    942    11  3262   145  793
# 5     트래블라이트       부산광역시 부산진구 서면로68번길 52   1165    24  4664   128  789
# 6      라이온호텔  부산광역시 부산진구 중앙대로691번가길 14-7   1081    21  4005   109  788
# 7  사우스반데코 호텔            부산광역시 부산진구 서면로 6   1153    22  4609   130  789
# 8      하운드호텔    부산광역시 부산진구 중앙대로691번가길 10   1081    21  4005   109  788

# %% [markdown]
# # 방사형 차트 시각화

# %%
from sklearn.preprocessing import StandardScaler

# Standardization 평균 0 / 분산 1
scaler = StandardScaler()   

scaler = scaler.fit_transform(hotel_df_radar.loc[:, ['편의시설', '업무시설', '식음시설', '교통시설', '관광지']])

scaler
# Out:
# array([[ 0.46876089,  0.58006955,  0.23480836, -0.95848559,  2.17832459],
#        [-1.0572054 , -1.0979888 , -1.0029934 ,  0.99592643,  0.39605902],
#        [-1.0572054 , -1.0979888 , -1.0029934 ,  0.99592643,  0.39605902],
#        [-1.0572054 , -1.0979888 , -1.0029934 ,  0.99592643,  0.39605902],
#        [-1.0572054 , -1.0979888 , -1.0029934 ,  0.99592643,  0.39605902],
#        [ 1.4449305 ,  1.32587326,  1.575607  , -0.14976337, -0.79211803],
#        [ 0.50242191,  0.76652048,  0.36355445, -1.43024022, -1.0891623 ],
#        [ 1.31028641,  0.95297141,  1.47444935, -0.01497634, -0.79211803],
#        [ 0.50242191,  0.76652048,  0.36355445, -1.43024022, -1.0891623 ]])

# %%
hotel_df_radar_sc = hotel_df_radar.copy()
hotel_df_radar_sc[['편의시설', '업무시설', '식음시설', '교통시설', '관광지']] = scaler

# %%
hotel_df_radar_sc
# Out:
#        숙박업소명                           주소      편의시설      업무시설      식음시설  \
# 0  (주)부산롯데호텔         부산광역시 부산진구 가야대로 772   0.468761  0.580070  0.234808
# 1       퀸스호텔           부산광역시 부산진구 부전로 56  -1.057205 -1.097989 -1.002993
# 2   부산비즈니스호텔           부산광역시 부산진구 부전로 67  -1.057205 -1.097989 -1.002993
# 3  TRT HOTEL         부산광역시 부산진구 부전로 33-1  -1.057205 -1.097989 -1.002993
# 4   (주)샤이어호텔         부산광역시 부산진구 부전로 18-5  -1.057205 -1.097989 -1.002993
# 5     트래블라이트       부산광역시 부산진구 서면로68번길 52   1.444930  1.325873  1.575607
# 6      라이온호텔  부산광역시 부산진구 중앙대로691번가길 14-7   0.502422  0.766520  0.363554
# 7  사우스반데코 호텔            부산광역시 부산진구 서면로 6   1.310286  0.952971  1.474449
# 8      하운드호텔    부산광역시 부산진구 중앙대로691번가길 10   0.502422  0.766520  0.363554
#
#        교통시설       관광지
# 0 -0.958486  2.178325
# 1  0.995926  0.396059
# 2  0.995926  0.396059
# 3  0.995926  0.396059
# 4  0.995926  0.396059
# 5 -0.149763 -0.792118
# 6 -1.430240 -1.089162
# 7 -0.014976 -0.792118
# 8 -1.430240 -1.089162

# %%
categories = ['편의시설', '업무시설', '식음시설', '교통시설', '관광지']
categories = [*categories, categories[0]]

# %%
hotel_grade = hotel_df_radar_sc.loc[0, ['편의시설', '업무시설', '식음시설', '교통시설', '관광지']].tolist()
hotel_grade = [*hotel_grade, hotel_grade[0]]

# %%
label_loc = np.linspace(start=0, stop=2*np.pi, num=len(hotel_grade))

# %%
plt.figure(figsize=(8,8))
ax = plt.subplot(polar=True)
plt.xticks(label_loc, labels=categories, fontsize=13)

for i in tqdm(range(len(hotel_df_radar_sc))):
  hotel_grade = hotel_df_radar_sc.loc[i, ['편의시설', '업무시설', '식음시설', '교통시설', '관광지']].tolist()
  hotel_grade = [*hotel_grade, hotel_grade[0]]

  ax.plot(label_loc, hotel_grade, label=hotel_df_radar.숙박업소명[i], linestyle='dashed')
  ax.fill(label_loc, hotel_grade, alpha=0.3)

ax.legend()
plt.show()
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 472.62it/s]

# %% [markdown]
# ✈ 1. 부산롯데호텔
#   2. 트래블라이트 -> 게하 제거 2등 버리자
#   3. 사우스반데코 -> 좋지만,,, 1등이 너무 좋다

# %%
# 관광 프로그램 제안을 위해 관광지 list를 뽑아보자
url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
params = {'query':'관광지',
          'x': hotel_df.loc[7, '경도'],
          'y': hotel_df.loc[7, '위도'],
          'radius': 10000} # 관광지만 10km
headers = {"Authorization": "KakaoAK ea955b4e90386bf89fcd94c7d362e516"} 
total = requests.get(url, params=params, headers=headers).json() # ['meta']['total_count']

total
# Out:
# {'documents': [{'address_name': '부산 수영구 광안동 192-20',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 해수욕장,해변',
#    'distance': '5582',
#    'id': '8202423',
#    'phone': '051-610-4744',
#    'place_name': '광안리해수욕장',
#    'place_url': 'http://place.map.kakao.com/8202423',
#    'road_address_name': '부산 수영구 광안해변로 219',
#    'x': '129.118976093583',
#    'y': '35.1531932736837'},
#   {'address_name': '부산 남구 문현동 1227-2',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 동물원 > 실내동물원',
#    'distance': '1057',
#    'id': '264928678',
#    'phone': '051-710-1022',
#    'place_name': '캐니언파크 부산점',
#    'place_url': 'http://place.map.kakao.com/264928678',
#    'road_address_name': '부산 남구 전포대로 133',
#    'x': '129.06547083683037',
#    'y': '35.14821048402504'},
#   {'address_name': '부산 부산진구 전포동 682',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '435',
#    'id': '25661344',
#    'phone': '',
#    'place_name': '전포카페거리',
#    'place_url': 'http://place.map.kakao.com/25661344',
#    'road_address_name': '부산 부산진구 전포대로209번길 26',
#    'x': '129.062569363766',
#    'y': '35.1554466988384'},
#   {'address_name': '부산 남구 대연동 산 53-58',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 전망대',
#    'distance': '2289',
#    'id': '27135397',
#    'phone': '070-7543-5249',
#    'place_name': '황령산전망쉼터',
#    'place_url': 'http://place.map.kakao.com/27135397',
#    'road_address_name': '부산 남구 황령산로 391-39',
#    'x': '129.082724691796',
#    'y': '35.1578845362561'},
#   {'address_name': '부산 부산진구 부전동 227-2',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마파크',
#    'distance': '307',
#    'id': '846455862',
#    'phone': '051-520-3636',
#    'place_name': '런닝맨 부산점',
#    'place_url': 'http://place.map.kakao.com/846455862',
#    'road_address_name': '부산 부산진구 중앙대로 672',
#    'x': '129.059606833427',
#    'y': '35.1530135123952'},
#   {'address_name': '부산 사하구 감천동 10-13',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소',
#    'distance': '7899',
#    'id': '21362956',
#    'phone': '051-204-1444',
#    'place_name': '감천문화마을',
#    'place_url': 'http://place.map.kakao.com/21362956',
#    'road_address_name': '부산 사하구 감내1로 200',
#    'x': '129.00942831915552',
#    'y': '35.09630012826786'},
#   {'address_name': '부산 동래구 온천동 137',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 온천',
#    'distance': '7641',
#    'id': '25618927',
#    'phone': '051-550-2200',
#    'place_name': '허심청 호텔농심',
#    'place_url': 'http://place.map.kakao.com/25618927',
#    'road_address_name': '부산 동래구 온천장로107번길 32',
#    'x': '129.08269838808098',
#    'y': '35.22109550998741'},
#   {'address_name': '부산 부산진구 전포동 50-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소 > 문화유적 > 봉수대',
#    'distance': '2214',
#    'id': '8692767',
#    'phone': '',
#    'place_name': '황령산 봉수대',
#    'place_url': 'http://place.map.kakao.com/8692767',
#    'road_address_name': '',
#    'x': '129.081975486375',
#    'y': '35.1572485849507'},
#   {'address_name': '부산 부산진구 범전동 429',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소 > 광장',
#    'distance': '1432',
#    'id': '24882535',
#    'phone': '',
#    'place_name': '송상현광장',
#    'place_url': 'http://place.map.kakao.com/24882535',
#    'road_address_name': '',
#    'x': '129.065975130789',
#    'y': '35.1663719933168'},
#   {'address_name': '부산 동구 초량동 994-213',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소',
#    'distance': '4699',
#    'id': '556297681',
#    'phone': '051-440-4611',
#    'place_name': '168계단모노레일',
#    'place_url': 'http://place.map.kakao.com/556297681',
#    'road_address_name': '부산 동구 영초길191번길 8-1',
#    'x': '129.035457591932',
#    'y': '35.1171911515383'},
#   {'address_name': '부산 동구 초량동 994-12',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '4689',
#    'id': '24544632',
#    'phone': '',
#    'place_name': '초량이바구길',
#    'place_url': 'http://place.map.kakao.com/24544632',
#    'road_address_name': '',
#    'x': '129.03669648381614',
#    'y': '35.116820678714'},
#   {'address_name': '부산 중구 보수동1가 151-1',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '6430',
#    'id': '427198875',
#    'phone': '',
#    'place_name': '보수동책방골목',
#    'place_url': 'http://place.map.kakao.com/427198875',
#    'road_address_name': '부산 중구 책방골목길 16',
#    'x': '129.026656923019',
#    'y': '35.1033668597923'},
#   {'address_name': '부산 중구 남포동3가 15-1',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '6795',
#    'id': '9650856',
#    'phone': '',
#    'place_name': 'BIFF광장',
#    'place_url': 'http://place.map.kakao.com/9650856',
#    'road_address_name': '',
#    'x': '129.029045595229',
#    'y': '35.0988678741728'},
#   {'address_name': '부산 부산진구 전포동 산 50-18',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 산',
#    'distance': '2211',
#    'id': '11204671',
#    'phone': '',
#    'place_name': '황령산',
#    'place_url': 'http://place.map.kakao.com/11204671',
#    'road_address_name': '',
#    'x': '129.08193869996194',
#    'y': '35.15726904283438'},
#   {'address_name': '부산 영도구 영선동4가 1044-6',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소',
#    'distance': '8670',
#    'id': '22875776',
#    'phone': '051-419-4067',
#    'place_name': '흰여울문화마을',
#    'place_url': 'http://place.map.kakao.com/22875776',
#    'road_address_name': '',
#    'x': '129.04528136992104',
#    'y': '35.077914827298564'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '관광지', 'region': [], 'selected_region': ''},
#   'total_count': 789}}
